# %%
import json 
import os

# %%
f = open('./static/dataset/ja-eum/k.json')
json_data = json.load(f)
f.close()
json_data[0]['landmarks']
# Out:
# [[211.2671058309508, 123.42912033773716, -0.0010310113430023193],
#  [265.537672684033, 137.25826485975261, 7.912355899810791],
#  [316.2875355490859, 170.22230224655675, 4.570704460144043],
#  [350.7352389716463, 198.83299782046961, 3.4070348739624023],
#  [377.33235283079466, 214.33237101835766, 1.4329845905303955],
#  [281.53591736155937, 215.94452695770684, -25.078197479248047],
#  [288.5456601852799, 275.14051563883, -17.638811111450195],
#  [284.57505786949275, 272.9616070496302, -4.214832305908203],
#  [277.72937671677073, 262.7755483992538, 3.353935718536377],
#  [245.41681644286146, 225.53526534495347, -24.64564323425293],
#  [268.67173761989613, 295.7827471159036, -19.82946014404297],
#  [275.5740264282886, 320.6606316572636, -8.43069839477539],
#  [273.76111958061335, 334.30142891106897, -4.847599983215332],
#  [212.5550427483487, 227.8899467512995, -20.112823486328125],
#  [230.96749648584859, 274.6657642577916, -10.06283187866211],
# ...

# %%
type(json_data[0])
# Out:
# dict

# %%
type(json_data[0])
# Out:
# dict

# %%
json_data[0].keys()
# Out:
# dict_keys(['handInViewConfidence', 'boundingBox', 'landmarks', 'annotations'])

# %%
json_data[0]['landmarks']
# Out:
# [[211.2671058309508, 123.42912033773716, -0.0010310113430023193],
#  [265.537672684033, 137.25826485975261, 7.912355899810791],
#  [316.2875355490859, 170.22230224655675, 4.570704460144043],
#  [350.7352389716463, 198.83299782046961, 3.4070348739624023],
#  [377.33235283079466, 214.33237101835766, 1.4329845905303955],
#  [281.53591736155937, 215.94452695770684, -25.078197479248047],
#  [288.5456601852799, 275.14051563883, -17.638811111450195],
#  [284.57505786949275, 272.9616070496302, -4.214832305908203],
#  [277.72937671677073, 262.7755483992538, 3.353935718536377],
#  [245.41681644286146, 225.53526534495347, -24.64564323425293],
#  [268.67173761989613, 295.7827471159036, -19.82946014404297],
#  [275.5740264282886, 320.6606316572636, -8.43069839477539],
#  [273.76111958061335, 334.30142891106897, -4.847599983215332],
#  [212.5550427483487, 227.8899467512995, -20.112823486328125],
#  [230.96749648584859, 274.6657642577916, -10.06283187866211],
# ...
